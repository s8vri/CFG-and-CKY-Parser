# %%
import collections
import itertools
import datetime

from nltk import Tree
from nltk.draw.util import CanvasFrame
from nltk.draw import TreeWidget
import nltk 

# %matplotlib inline

grammar = nltk.data.load("grammars/large_grammars/atis.cfg") #load the grammar
#sentences = nltk.data.load("grammars/large_grammars/atis_sentences.txt") #load the raw sentences
#test_sentences = nltk.parse.util.extract_test_sentences(sentences) #extract the test sentences

data = open("atis/atis-grammar-cnf.cfg",'r').read() #read the file
grammar = nltk.grammar.CFG.fromstring(data)
test_sentences = nltk.data.load("atis/atis-test-sentences.txt") #load the test sentences
test_sentences = nltk.parse.util.extract_test_sentences(test_sentences) #extract the test sentences
grammar.productions(lhs = nltk.grammar.Nonterminal("SIGMA")) #convert the string to Nonterminal and get production rule for that Nonterminal
start_symbol = grammar.start()

def cky_recognizer(sentence):
    """
    This function searches the language of the CFG for a given sentence.
    Parameters:
    Sentence (list): this is the list of a string.
    Return:
    False: if the sentence is not in the grammar.
    Dictionary(defaultdict with list), Matrix(list of list of sets) if the sentence is in the grammar.
    """
    dictionary = collections.defaultdict(list)
    n = len(sentence)
    matrix = [[set() for j in range(n+1) ] for i in range(n+1)] #define matrix as set of nonterminal symbols

    for i in range(0,n): #iterate over all positions in string
        for rule in grammar.productions(rhs = sentence[i]): #look at rhs terminals of production rules
            matrix[i][i+1].add(rule.lhs())
            dictionary[(rule.lhs(),i,i+1)].append(sentence[i]) 
    for i in range(2, n+1): #iterate over substrings of increasing length
        for j in range(0,n-i+1): #iterate over start position of respective substring
            for k in range(1,i):
                B = matrix[j][j+k] #left part of substring j-j+k
                C = matrix[j+k][j+i] #right part of substrink j+k,j+i
                for each_b in B: #iterative over all nonterminal symbols found for left substring
                    for each_production in grammar.productions(rhs = each_b):
                        #iterate over all nonterminal symbols found for right substring
                        if each_production.rhs()[1] in C:
                            matrix[j][j+i].add(each_production.lhs())
                            dictionary[(each_production.lhs(),j,j+i)].append((each_production.rhs()[0],each_production.rhs()[1],j,j+k,j+i)) #append all found nonterminal symbols to list
    if start_symbol in matrix[0][n]: #checking if given sentence has start symbol or not
        return dictionary, matrix
    else: 
        print("The given sentence is not in the language of CFG\n\n")
        return None, None
    
def tree_parser(parent_node,i,j, backpointer):
    """
    This function extracts the set of all parse trees from the backpointers in the chart.
    Parameters: 
    parent_node(nltk.grammar.Nonterminal)
    i(int): row value for parent in matrix
    j(int): column value for parent in matrix
    backpointer(dict): from cky recognizer
    Return:
    List of trees
    """
    trees = []
    parent_values = backpointer[(parent_node,i,j)]
    
    for parent_value in parent_values: 
        if isinstance(parent_value,str): #checking type, whether the parent has terminal or nonterminal
            return [(parent_node,parent_value)]
        else:
            leftchild = tree_parser(parent_value[0],parent_value[2],parent_value[3],backpointer) #getting tree for leftchild
            rightchild = tree_parser(parent_value[1],parent_value[3],parent_value[4],backpointer) #getting tree for rightchild
            for left,right in itertools.product(leftchild,rightchild): #getting cartesian product multiple trees from the left and the right chlid
                trees.append((parent_node,left,right)) #appending trees to list
    return trees

# %% [markdown]
# ### Part 1 - Recognizer: checks for sentence in test sentences, if the sentence is in grammar ###

# %%
time_recognizer = datetime.datetime.now() 

for i,sentence in enumerate(test_sentences): 
    print('sentence '+ str(i) + ': ' + ' '.join(sentence[0]))
    backpointer, chart = cky_recognizer(sentence[0])
    if backpointer and chart:
        print("The given CKY_Parser sentence is in the language of CFG \n\n")

time_n = datetime.datetime.now()
print("The total time taken was:", (time_n-time_recognizer).total_seconds(), "seconds") #measure total time to test, if all sentences are in the grammar
# Out:
# sentence 0: prices .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 1: show availability .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 2: show the flights .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 3: milwaukee to detroit .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 4: indianapolis to seattle .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 5: list round trips .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 6: list saturday flights .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 7: what aircraft is this .
# The given sentence is not in the language of CFG
#
#
# sentence 8: list these economy fares .
# The given sentence is not in the language of CFG
#
#
# sentence 9: list these city destinations .
# The given sentence is not in the language of CFG
#
#
# sentence 10: what is the fare .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 11: which flights are cheapest .
# The given sentence is not in the language of CFG
#
#
# sentence 12: list flights from cleveland .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 13: what are the costs .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 14: can i have the fare .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 15: what is e w r .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 16: oakland to salt lake city .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 17: show me northwest flights to detroit .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 18: i want to leave before noon .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 19: what flights leave boston to pittsburgh .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 20: i 'd like an afternoon flight .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 21: are any fares cheaper than these .
# The given sentence is not in the language of CFG
#
#
# sentence 22: what is the flying time from .
# The given sentence is not in the language of CFG
#
#
# sentence 23: which flights use a large plane .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 24: what area does canadian airlines international service .
# The given sentence is not in the language of CFG
#
#
# sentence 25: what flights leave las vegas to oakland .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 26: show me the airlines and flight numbers .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 27: what airlines fly from toronto to detroit .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 28: which city is cheapest to fly into .
# The given sentence is not in the language of CFG
#
#
# sentence 29: does delta fly to boston from denver .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 30: what is the duration of this flight .
# The given sentence is not in the language of CFG
#
#
# sentence 31: what flights leave los angeles arriving in minneapolis .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 32: i can only spend a hundred fifty dollars .
# The given sentence is not in the language of CFG
#
#
# sentence 33: i 'd like to leave on a saturday .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 34: orlando to kansas city and then to minneapolis .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 35: is there a flight from memphis to los angeles .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 36: what if i wanted to leave on may fifth .
# The given sentence is not in the language of CFG
#
#
# sentence 37: list u s air flights from dallas to boston .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 38: i need a flight from philadelphia to westchester county .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 39: what is the cheapest ticket from memphis to miami .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 40: find a flight from washington d c to milwaukee .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 41: find a flight from washington d c to montreal .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 42: show american flights after twelve p.m. from miami to chicago .
# The given sentence is not in the language of CFG
#
#
# sentence 43: how far is it from the airport to the city .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 44: list those flights that stop over in salt lake city .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 45: i want first class on flight one one one nine .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 46: please show me all flights from montreal to las vegas .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 47: i need the shortest evening flight from tampa to cincinnati .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 48: how much is the fare limousine san francisco to downtown .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 49: i need a flight from pittsburgh to newark on monday .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 50: what meals are served on flight h p five four .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 51: i 'll be leaving on a friday at four o'clock .
# The given sentence is not in the language of CFG
#
#
# sentence 52: i 'd like to leave before eight o'clock at night .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 53: please tell me the round trip cost for these flights .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 54: i would like a flight from orlando to kansas city .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 55: what is the cheapest one way flight from columbus to indianapolis .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 56: count the number of flights between nine a.m. and twelve noon .
# The given sentence is not in the language of CFG
#
#
# sentence 57: i need a flight from los angeles to minneapolis thursday afternoon .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 58: please list flights departing from toronto canada to washington on saturday .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 59: please list costs of round trip fares from denver to atlanta .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 60: please give me a one way flight from washington to cincinnati .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 61: does united flight four seven four slash fourteen eighty four serve dinner .
# The given sentence is not in the language of CFG
#
#
# sentence 62: show me flights from detroit to san diego on tuesday may third .
# The given sentence is not in the language of CFG
#
#
# sentence 63: i would like to find a flight from charlotte to las vegas .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 64: the flight going to san diego from toronto should stop in denver .
# The given sentence is not in the language of CFG
#
#
# sentence 65: show me flights from chicago to kansas city leaving around seven p.m. thursday .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 66: can you tell me about the flights from saint petersburg to toronto again .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 67: i would like to leave on thursday morning may fifth before six a.m .
# The given sentence is not in the language of CFG
#
#
# sentence 68: i need a first class round trip airfare from detroit to saint petersburg .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 69: how far is the airport from new york 's la guardia to downtown .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 70: i 'd like to fly from buffalo to either orlando or long beach .
# The given sentence is not in the language of CFG
#
#
# sentence 71: please list all flights from pittsburgh to toronto on nationair and canadian airlines international .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 72: how long is the stop in dallas on flight d l nine thirty one .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 73: please show me all first class flights from pittsburgh to newark on monday morning .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 74: please show me all first class flights from indianapolis to memphis leaving monday morning .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 75: please show me all flights from ontario to salt lake city leaving monday morning .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 76: i need an american airlines flight number from chicago to philadelphia departing six p.m .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 77: for american airlines i need round trip airfare from new york to san diego .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 78: how much does a first class round trip ticket from detroit to saint petersburg cost .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 79: what flights departing montreal have less than one hundred and fifty dollars round trip fare .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 80: i need a flight from charlotte to las vegas that makes a stop in saint louis .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 81: please show me the flights from chicago to detroit that arrive at six p.m. next tuesday .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 82: what flights are available between chicago and indianapolis next wednesday between eleven a.m. and one p.m .
# The given sentence is not in the language of CFG
#
#
# sentence 83: how many flights leave from lester b pearson international airport between nine a.m. and twelve noon .
# The given sentence is not in the language of CFG
#
#
# sentence 84: how many times a day can i fly from boston to pittsburgh to newark to boston .
# The given sentence is not in the language of CFG
#
#
# sentence 85: what flights do you have available on march twenty fourth leaving minneapolis arriving in seattle by .
# The given sentence is not in the language of CFG
#
#
# sentence 86: how much does flight number a nineteen cost from new york to los angeles on monday morning .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 87: i 'd like to fly out of chicago for less than a hundred fifty dollars round trip .
# The given sentence is not in the language of CFG
#
#
# sentence 88: what type of aircraft is used on a flight from cleveland to dallas that leaves before noon .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 89: what kind of aircraft is american 's flight fifteen oh one that departs at six fifty nine p.m .
# The given sentence is not in the language of CFG
#
#
# sentence 90: how much does first class on that flight cost and how much does coach on that flight cost .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 91: please book a one way coach fare from chicago to indianapolis on united flight two ninety two next wednesday .
# The given sentence is not in the language of CFG
#
#
# sentence 92: please give me the number of flights that depart from lester b pearson international airport on april twenty fifth .
# The given sentence is not in the language of CFG
#
#
# sentence 93: please list the flights leaving newark stopping over in seattle for approximately five hours and then on to san francisco .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 94: i 'd like the cheapest round trip ticket from minneapolis to san diego arriving in san diego before seven p.m .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 95: what is the cheapest first class ticket available flying from new york to miami one way but also round trip .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 96: what is the cheapest one way flight from phoenix to san diego that arrives in the morning on thursday june second .
# The given CKY_Parser sentence is in the language of CFG
#
#
# sentence 97: i 'd like to fly from indianapolis to houston on t w a and the plane should arrive around eleven a.m .
# The given sentence is not in the language of CFG
#
#
# The total time taken was: 43.738257 seconds

# %%
ungrammaticals = ["the plane crashed in the middle of the ocean",
"the company produces mechanical parts for airplane engines",
"the airport is not well equipped to handle aircraft of such size",
"the accident had a lasting influence on the industry",
"the crew were all russian while the passengers were of various nationalities"]

for i,ungrammatical in enumerate(ungrammaticals): #iterate list, print ungrammatical sentences
    sentence = ungrammatical.split() #split each sentence
    print('sentence '+ str(i) + ': ' + ' '.join(sentence)+ "\n")
    backpointer, chart = cky_recognizer(sentence) #call CKY recognizer
    if backpointer and chart:
        print("The given CKY_Parser CKY_Parser sentence is in the language of CFG \n\n") #print if ungrammatical sentences are in grammar or not
# Out:
# sentence 0: the plane crashed in the middle of the ocean
#
# The given sentence is not in the language of CFG
#
#
# sentence 1: the company produces mechanical parts for airplane engines
#
# The given sentence is not in the language of CFG
#
#
# sentence 2: the airport is not well equipped to handle aircraft of such size
#
# The given sentence is not in the language of CFG
#
#
# sentence 3: the accident had a lasting influence on the industry
#
# The given sentence is not in the language of CFG
#
#
# sentence 4: the crew were all russian while the passengers were of various nationalities
#
# The given sentence is not in the language of CFG

# %% [markdown]
# Feeding the recognizer ungrammatical sentences (ungrammaticals.txt), i.e. sentences which are not captured by the language of the CFG, one can observe that the recognizer rejects them.

# %% [markdown]
# ### Part 2 - Parser: extracts the set of all parse trees from the backpointers in the chart###

# %%
time_parser = datetime.datetime.now()

output_file = open('trees_number.txt',"w") #open and write file
for sentence in test_sentences: 
    n = len(sentence)
    backpointer, chart = cky_recognizer(sentence[0]) #recognizer
    if backpointer and chart:
        parses = tree_parser(parent_node=start_symbol,i= 0,j=len(sentence[0]),backpointer=backpointer) 
        output_file.write((" ").join(sentence[0])+'\t'+ str(len(parses))+'\n') #writing file sentences and number of parses
    else:
        output_file.write((" ").join(sentence[0])+'\t'+str(0)+'\n') #writing file sentences and parses = 0
output_file.close()
      
time_n = datetime.datetime.now()      
print("The total time taken was:", (time_n-time_parser).total_seconds(), "seconds") #measure total time taken to parse all sentences and print parse trees
# Out:
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The given sentence is not in the language of CFG
#
#
# The total time taken was: 49.783717 seconds

# %%
sentences =open("trees_number.txt", 'r') #load the file with test sentences and number of parses
filtered =[]
for sentence in sentences: 
    if int(sentence.split('\t')[-1]) <6 and int(sentence.split('\t')[-1]) >1: #filter sentences with 2-5 parses
        filtered.append((sentence.split('\t')[0].split(), int(sentence.split('\t')[-1])))

# %%
def saving_tree(sentence, i):
    """
    This function saves the filtered parse trees with two to five parses
    Parameters:
    sentence
    i(int): position of sentence
    """
    backpointer, chart = cky_recognizer(sentence[0])
    if backpointer and chart:
        parses = tree_parser(parent_node=start_symbol,i= 0,j=len(sentence[0]),backpointer=backpointer)
        for j,parse in enumerate(parses):
            cf = CanvasFrame()
            t = Tree.fromstring(str(parse).replace(',',''))
            t.pretty_print()
            #t.draw()
            tc = TreeWidget(cf.canvas(),t)
            cf.add_widget(tc,10,10)
            cf.print_to_file('images/'+str(i) + '-'+str(j)+'.ps')
            cf.destroy()

# %%
for I,each in enumerate(filtered):
    print(each)
    print(I)
    saving_tree(each,I) #saving image of tree
# Out:
# (['prices', '.'], 2)
# 0
#          SIGMA
#     _______|________
# NOUN_NNS       pt_char_per
#    |                |
# 'prices'           '.'
#
#          SIGMA
#     _______|________
# VERB_VBZ       pt_char_per
#    |                |
# 'prices'           '.'
#
# (['show', 'availability', '.'], 3)
# 1
#             SIGMA
#     __________|_________
#    |                   JKA
#    |           _________|_______
# VERB_VB     NP_NN          pt_char_per
#    |          |                 |
#  'show' 'availability'         '.'
#
#             SIGMA
#     __________|_________
#    |                   JWB
#    |           _________|_______
# NOUN_NN    AVPNP_NN        pt_char_per
#    |          |                 |
#  'show' 'availability'         '.'
#
#            SIGMA
#    __________|_________
#   |                   JXI
#   |           _________|_______
# NP_NN     NOUN_NN         pt_char_per
#   |          |                 |
# 'show' 'availability'         '.'
#
# (['show', 'the', 'flights', '.'], 2)
# 2
#                SIGMA
#     _____________|________
#    |                     JKB
#    |              ________|__________
#    |           NP_NNS                |
#    |       ______|________           |
# VERB_VB AVP_RB         NOUN_NNS pt_char_per
#    |      |               |          |
#  'show' 'the'         'flights'     '.'
#
#                SIGMA
#     _____________|________
#    |                     JKB
#    |              ________|__________
#    |           NP_NNS                |
#    |       ______|________           |
# VERB_VB ADJ_AT         NOUN_NNS pt_char_per
#    |      |               |          |
#  'show' 'the'         'flights'     '.'
#
# (['milwaukee', 'to', 'detroit', '.'], 2)
# 3
#                     SIGMA
#       ________________|_______
#      |                       KEX
#      |                 _______|__________
#      |              PP_NP                |
#      |          ______|_______           |
#   NOUN_NP   PREP_IN        NOUN_NP  pt_char_per
#      |         |              |          |
# 'milwaukee'   'to'        'detroit'     '.'
#
#                           SIGMA
#                _____________|______________
#             NP_NP                         KFD
#       ________|______                ______|_______
#   NOUN_NP         PREP_IN        NOUN_NP      pt_char_per
#      |               |              |              |
# 'milwaukee'         'to'        'detroit'         '.'
#
# (['indianapolis', 'to', 'seattle', '.'], 2)
# 4
#                        SIGMA
#        __________________|_______
#       |                         KEX
#       |                   _______|__________
#       |                PP_NP                |
#       |            ______|_______           |
#    NOUN_NP     PREP_IN        NOUN_NP  pt_char_per
#       |           |              |          |
# 'indianapolis'   'to'        'seattle'     '.'
#
#                              SIGMA
#                   _____________|______________
#                NP_NP                         KFD
#        __________|______                ______|_______
#    NOUN_NP           PREP_IN        NOUN_NP      pt_char_per
#       |                 |              |              |
# 'indianapolis'         'to'        'seattle'         '.'
#
# (['list', 'saturday', 'flights', '.'], 5)
# 5
#                    SIGMA
#     _________________|_______
#    |                        GXA
#    |         ________________|______
#    |        |                      GXB
#    |        |                 ______|_______
# VERB_VB   NP_NP            NP_NNS      pt_char_per
#    |        |                |              |
#  'list' 'saturday'       'flights'         '.'
#
#                    SIGMA
#     _________________|________
#    |                         JKB
#    |                  ________|__________
#    |               NP_NNS                |
#    |         ________|________           |
# VERB_VB   NP_NP            NOUN_NNS pt_char_per
#    |        |                 |          |
#  'list' 'saturday'        'flights'     '.'
#
#                      SIGMA
#     ___________________|_________
#    |                            JWS
#    |                    _________|__________
#    |               RELCL_VBZ                |
#    |         __________|_________           |
# NOUN_NN   NP_NP               VERB_VBZ pt_char_per
#    |        |                    |          |
#  'list' 'saturday'           'flights'     '.'
#
#                         SIGMA
#           ________________|______________
#        NP_NP                            KCJ
#    ______|_______                  ______|_______
# NP_NN         NOUN_NP          NOUN_NNS     pt_char_per
#   |              |                |              |
# 'list'       'saturday'       'flights'         '.'
#
#                          SIGMA
#            ________________|______________
#         NP_NN                            KCD
#     ______|_______                  ______|_______
# NOUN_NN       NAPPOS_NP         NOUN_NNS     pt_char_per
#    |              |                |              |
#  'list'       'saturday'       'flights'         '.'
#
# (['what', 'is', 'the', 'fare', '.'], 2)
# 6
#                 SIGMA
#    _______________|______
#   |                     GDO
#   |        ______________|______
#   |       |                    GDP
#   |       |               ______|_________
#   |       |            NP_NN              |
#   |       |        ______|______          |
# NP_DT  VERB_BEZ ADJ_AT       NOUN_NN pt_char_per
#   |       |       |             |         |
# 'what'   'is'   'the'         'fare'     '.'
#
#                 SIGMA
#    _______________|_____
#   |                    KGC
#   |        _____________|_____
#   |       |                 NP_NN
#   |       |        ___________|_____
#   |       |       |                JUO
#   |       |       |            _____|_______
# NP_DT  VERB_BEZ ADJ_AT     NOUN_NN     pt_char_per
#   |       |       |           |             |
# 'what'   'is'   'the'       'fare'         '.'
#
# (['list', 'flights', 'from', 'cleveland', '.'], 5)
# 7
#                           SIGMA
#     ________________________|_____
#    |                             GVY
#    |                 _____________|_______________
#    |              NP_NNS                         GVZ
#    |         _______|_______               _______|_______
# VERB_VB  NOUN_NNS        PREP_IN       AVPNP_NP      pt_char_per
#    |        |               |             |               |
#  'list' 'flights'         'from'     'cleveland'         '.'
#
#                    SIGMA
#     _________________|______
#    |                       GWQ
#    |         _______________|________
#    |        |                       GWR
#    |        |                ________|___________
#    |        |             PP_NP                  |
#    |        |         ______|________            |
# VERB_VB   NP_NNS  PREP_IN         NOUN_NP   pt_char_per
#    |        |        |               |           |
#  'list' 'flights'  'from'       'cleveland'     '.'
#                    SIGMA
#     _________________|______
#    |                       JKB
#    |                  ______|____________________
#    |               NP_NNS                        |
#    |         ________|______                     |
#    |        |             PP_NP                  |
#    |        |         ______|________            |
# VERB_VB  NOUN_NNS PREP_IN         NOUN_NP   pt_char_per
#    |        |        |               |           |
#  'list' 'flights'  'from'       'cleveland'     '.'
#
#                   SIGMA
#    _________________|______
#   |                       GRY
#   |         _______________|________
#   |        |                       GRZ
#   |        |                ________|___________
#   |        |             PP_NP                  |
#   |        |         ______|________            |
# NP_NN   VERB_VBZ PREP_IN         NOUN_NP   pt_char_per
#   |        |        |               |           |
# 'list' 'flights'  'from'       'cleveland'     '.'
#
#                   SIGMA
#    _________________|______
#   |                       HXS
#   |         _______________|________
#   |        |                       HXT
#   |        |                ________|___________
#   |        |             PP_NP                  |
#   |        |         ______|________            |
# NP_NN   NOUN_NNS PREP_IN         NOUN_NP   pt_char_per
#   |        |        |               |           |
# 'list' 'flights'  'from'       'cleveland'     '.'
#
# (['what', 'are', 'the', 'costs', '.'], 4)
# 8
#                    SIGMA
#    __________________|______
#   |                        GAE
#   |          _______________|_______
#   |         |                      GAF
#   |         |                _______|__________
#   |         |             NP_NNS               |
#   |         |         ______|_______           |
# NP_DT  pt_verb_ber AVP_RB        NOUN_NNS pt_char_per
#   |         |        |              |          |
# 'what'    'are'    'the'         'costs'      '.'
#
#                    SIGMA
#    __________________|______
#   |                        GAE
#   |          _______________|_______
#   |         |                      GAF
#   |         |                _______|__________
#   |         |             NP_NNS               |
#   |         |         ______|_______           |
# NP_DT  pt_verb_ber ADJ_AT        NOUN_NNS pt_char_per
#   |         |        |              |          |
# 'what'    'are'    'the'         'costs'      '.'
#
#                    SIGMA
#    __________________|_____
#   |                       KFW
#   |          ______________|_____
#   |         |                  NP_NNS
#   |         |         ___________|______
#   |         |        |                 KAT
#   |         |        |            ______|_______
# NP_DT  pt_verb_ber AVP_RB     NOUN_NNS     pt_char_per
#   |         |        |           |              |
# 'what'    'are'    'the'      'costs'          '.'
#
#                    SIGMA
#    __________________|_____
#   |                       KFW
#   |          ______________|_____
#   |         |                  NP_NNS
#   |         |         ___________|______
#   |         |        |                 JZK
#   |         |        |            ______|_______
# NP_DT  pt_verb_ber ADJ_AT     NOUN_NNS     pt_char_per
#   |         |        |           |              |
# 'what'    'are'    'the'      'costs'          '.'
#
# (['what', 'flights', 'leave', 'boston', 'to', 'pittsburgh', '.'], 3)
# 9
#                                   SIGMA
#            _________________________|________
#           |                                 DJP
#           |                  ________________|______
#           |                 |                      DJQ
#           |                 |        _______________|________
#           |                 |       |                       DJR
#           |                 |       |                ________|____________
#         NP_NNS              |       |             PP_NP                   |
#     ______|________         |       |         ______|________             |
# ADJ_WPS         NOUN_NNS VERB_VB  NP_NP   PREP_IN         NOUN_NP    pt_char_per
#    |               |        |       |        |               |            |
#  'what'        'flights' 'leave' 'boston'   'to'        'pittsburgh'     '.'
#
#                                   SIGMA
#            _________________________|________
#           |                                 GMA
#           |                  ________________|______
#           |                 |                      GMB
#           |                 |                 ______|_____________________
#           |                 |              NP_NP                          |
#           |                 |        ________|______                      |
#         NP_NNS              |       |             PP_NP                   |
#     ______|________         |       |         ______|________             |
# ADJ_WPS         NOUN_NNS VERB_VB NOUN_NP  PREP_IN         NOUN_NP    pt_char_per
#    |               |        |       |        |               |            |
#  'what'        'flights' 'leave' 'boston'   'to'        'pittsburgh'     '.'
#
#                                   SIGMA
#            _________________________|______________
#           |                                       GMA
#           |                  ______________________|_____
#           |                 |                           GMB
#           |                 |                       _____|____________________
#           |                 |                    NP_NP                        |
#           |                 |                ______|_____________             |
#         NP_NNS              |             NP_NP                  |            |
#     ______|________         |        _______|______              |            |
# ADJ_WPS         NOUN_NNS VERB_VB NOUN_NP        PREP_IN       NOUN_NP    pt_char_per
#    |               |        |       |              |             |            |
#  'what'        'flights' 'leave' 'boston'         'to'      'pittsburgh'     '.'
#
# (['what', 'flights', 'leave', 'las', 'vegas', 'to', 'oakland', '.'], 3)
# 10
#                                  SIGMA
#            ________________________|____________
#           |                                    DJP
#           |                  ___________________|_______
#           |                 |                          DJQ
#           |                 |             ______________|______________
#           |                 |            |                            DJR
#           |                 |            |                      _______|__________
#         NP_NNS              |          NP_NP                 PP_NP                |
#     ______|________         |       _____|______         ______|_______           |
# ADJ_WPS         NOUN_NNS VERB_VB  las         vegas  PREP_IN        NOUN_NP  pt_char_per
#    |               |        |      |            |       |              |          |
#  'what'        'flights' 'leave' 'las'       'vegas'   'to'        'oakland'     '.'
#                                  SIGMA
#            ________________________|______________
#           |                                      GMA
#           |                  _____________________|_____________
#           |                 |                                  GMB
#           |                 |                             ______|_________________________
#           |                 |                          NP_NP                              |
#           |                 |              ______________|_____________                   |
#         NP_NNS              |          NOUN_NP                       PP_NP                |
#     ______|________         |       ______|_______               ______|_______           |
# ADJ_WPS         NOUN_NNS VERB_VB  las           vegas        PREP_IN        NOUN_NP  pt_char_per
#    |               |        |      |              |             |              |          |
#  'what'        'flights' 'leave' 'las'         'vegas'         'to'        'oakland'     '.'
#
#                                  SIGMA
#            ________________________|______________
#           |                                      GMA
#           |                  _____________________|_____________
#           |                 |                                  GMB
#           |                 |                             ______|___________________
#           |                 |                          NP_NP                        |
#           |                 |                      ______|_______________           |
#           |                 |                   NP_NP                    |          |
#           |                 |              _______|_____________         |          |
#         NP_NNS              |          NOUN_NP                  |        |          |
#     ______|________         |       ______|_______              |        |          |
# ADJ_WPS         NOUN_NNS VERB_VB  las           vegas        PREP_IN  NOUN_NP  pt_char_per
#    |               |        |      |              |             |        |          |
#  'what'        'flights' 'leave' 'las'         'vegas'         'to'  'oakland'     '.'
#
# (['what', 'is', 'the', 'cheapest', 'ticket', 'from', 'memphis', 'to', 'miami', '.'], 5)
# 11
#         SIGMA
#    _______|________________
#   |                       CUJ
#   |        ________________|______________________
#   |       |                                      CUK
#   |       |                 ______________________|_______________________
#   |       |                |                                             CUL
#   |       |                |                                        ______|_________________________
#   |       |                |                                     PP_NP                              |
#   |       |                |                       ________________|______                          |
#   |       |              NP_NN                    |                      KLK                        |
#   |       |        ________|_______               |         ______________|______                   |
#   |       |       |               JTT             |        |                   PP_NPS               |
#   |       |       |         _______|_____         |        |               ______|_______           |
# NP_DT  VERB_BEZ ADJ_AT  AJP_JJT       NOUN_NN  PREP_IN  NOUN_NP        PREP_IN        NOUN_NPS pt_char_per
#   |       |       |        |             |        |        |              |              |          |
# 'what'   'is'   'the'  'cheapest'     'ticket'  'from' 'memphis'         'to'         'miami'      '.'
#
#         SIGMA
#    _______|________________
#   |                       CUM
#   |        ________________|______________________
#   |       |                                      CUN
#   |       |                 ______________________|________________________
#   |       |                |                                              CUO
#   |       |                |                                        _______|__________________
#   |       |                |                                     PP_NPS                       |
#   |       |                |                       ________________|_______                   |
#   |       |              NP_NN                    |                       KMH                 |
#   |       |        ________|_______               |                 _______|_______           |
#   |       |       |               JTT             |              NP_NP             |          |
#   |       |       |         _______|_____         |         _______|_______        |          |
# NP_DT  VERB_BEZ ADJ_AT  AJP_JJT       NOUN_NN  PREP_IN  NOUN_NP         PREP_IN NOUN_NPS pt_char_per
#   |       |       |        |             |        |        |               |       |          |
# 'what'   'is'   'the'  'cheapest'     'ticket'  'from' 'memphis'          'to'  'miami'      '.'
#
#         SIGMA
#    _______|________________
#   |                       CUM
#   |        ________________|______________________
#   |       |                                      CUN
#   |       |                           ____________|______________________________________
#   |       |                        NP_NN                                                 |
#   |       |        __________________|______                                             |
#   |       |       |                        HIE                                           |
#   |       |       |         ________________|_____                                       |
#   |       |       |        |                     HIF                                    CUO
#   |       |       |        |          ____________|______                         _______|__________
#   |       |       |        |         |                 PP_NP                   PP_NPS               |
#   |       |       |        |         |             ______|_______          ______|_______           |
# NP_DT  VERB_BEZ ADJ_AT  AJP_JJT   NOUN_NN      PREP_IN        NOUN_NP  PREP_IN        NOUN_NPS pt_char_per
#   |       |       |        |         |            |              |        |              |          |
# 'what'   'is'   'the'  'cheapest' 'ticket'      'from'       'memphis'   'to'         'miami'      '.'
#
#         SIGMA
#    _______|________________
#   |                       GDO
#   |        ________________|__________________
#   |       |                                  GDP
#   |       |                 __________________|_________________________________________________
#   |       |              NP_NN                                                                  |
#   |       |        ________|__________________                                                  |
#   |       |       |                          HIE                                                |
#   |       |       |         __________________|________                                         |
#   |       |       |        |                          HIF                                       |
#   |       |       |        |          _________________|_______                                 |
#   |       |       |        |         |                       PP_NP                              |
#   |       |       |        |         |         ________________|______                          |
#   |       |       |        |         |        |                      KLK                        |
#   |       |       |        |         |        |         ______________|______                   |
#   |       |       |        |         |        |        |                   PP_NPS               |
#   |       |       |        |         |        |        |               ______|_______           |
# NP_DT  VERB_BEZ ADJ_AT  AJP_JJT   NOUN_NN  PREP_IN  NOUN_NP        PREP_IN        NOUN_NPS pt_char_per
#   |       |       |        |         |        |        |              |              |          |
# 'what'   'is'   'the'  'cheapest' 'ticket'  'from' 'memphis'         'to'         'miami'      '.'
#                                          SIGMA
#    ________________________________________|____________
#   |                                                    GDS
#   |        _____________________________________________|________
#   |       |                                                     GDT
#   |       |                                              ________|__________________________________
#   |       |                                           NP_NP                                         |
#   |       |                          ___________________|_________________                          |
#   |       |                       NP_NN                                   |                         |
#   |       |        _________________|______                               |                         |
#   |       |       |                       HIG                            KEZ                        |
#   |       |       |         _______________|______                ________|______                   |
#   |       |       |        |                     HIH             |             PP_NPS               |
#   |       |       |        |                ______|_____         |         ______|_______           |
# NP_DT  VERB_BEZ ADJ_AT  AJP_JJT         NOUN_NN      PREP_IN  NOUN_NP  PREP_IN        NOUN_NPS pt_char_per
#   |       |       |        |               |            |        |        |              |          |
# 'what'   'is'   'the'  'cheapest'       'ticket'      'from' 'memphis'   'to'         'miami'      '.'
#
# (['i', "'d", 'like', 'to', 'leave', 'before', 'eight', "o'clock", 'at', 'night', '.'], 5)
# 12
#          SIGMA
#     _______|_______
#    |              DLL
#    |        _______|____________
#    |       |                   DLM
#    |       |        ____________|_________________
#    |       |       |                             DLN
#    |       |       |             _________________|_____________________________________________________
#    |       |       |         INFCL_VB                                                                   |
#    |       |       |      ______|_________________                                                      |
#    |       |       |     |                       JLN                                                    |
#    |       |       |     |       _________________|________________                                     |
#    |       |       |     |      |                                PP_CD                                  |
#    |       |       |     |      |         _________________________|______                              |
#    |       |       |     |      |        |                               KHJ                            |
#    |       |       |     |      |        |                 _______________|____________                 |
#    |       |       |     |      |        |             NOUN_CD                       PP_JJ              |
#    |       |       |     |      |        |         _______|________              ______|______          |
# NP_PPSS VERB_MD VERB_VB  to  VERB_VB  PREP_IN   eight          o___clock     PREP_IN        ADJ_JJ pt_char_per
#    |       |       |     |      |        |        |                |            |             |         |
#   'i'     "'d"   'like' 'to' 'leave'  'before' 'eight'         "o'clock"       'at'        'night'     '.'
#
#          SIGMA
#     _______|_______
#    |              DLL
#    |        _______|____________
#    |       |                   DLM
#    |       |        ____________|_________________
#    |       |       |                             DLN
#    |       |       |             _________________|_____________________________________________________
#    |       |       |         INFCL_VB                                                                   |
#    |       |       |      ______|_________________                                                      |
#    |       |       |     |                       JLN                                                    |
#    |       |       |     |       _________________|________________                                     |
#    |       |       |     |      |                                PP_CD                                  |
#    |       |       |     |      |         _________________________|______                              |
#    |       |       |     |      |        |                               KHK                            |
#    |       |       |     |      |        |                 _______________|____________                 |
#    |       |       |     |      |        |             NOUN_CD                       PP_NN              |
#    |       |       |     |      |        |         _______|________              ______|______          |
# NP_PPSS VERB_MD VERB_VB  to  VERB_VB  PREP_IN   eight          o___clock     PREP_IN       NOUN_NN pt_char_per
#    |       |       |     |      |        |        |                |            |             |         |
#   'i'     "'d"   'like' 'to' 'leave'  'before' 'eight'         "o'clock"       'at'        'night'     '.'
#
#          SIGMA
#     _______|_______
#    |              DLX
#    |        _______|_______________
#    |       |                      DLY
#    |       |        _______________|________________
#    |       |       |                               DLZ
#    |       |       |                ________________|_____________________________________________________
#    |       |       |             PP_NN                                                                    |
#    |       |       |        _______|________________                                                      |
#    |       |       |       |                       KIN                                                    |
#    |       |       |       |        ________________|________________                                     |
#    |       |       |       |       |                               PP_CD                                  |
#    |       |       |       |       |        _________________________|______                              |
#    |       |       |       |       |       |                               KHJ                            |
#    |       |       |       |       |       |                 _______________|____________                 |
#    |       |       |       |       |       |             NOUN_CD                       PP_JJ              |
#    |       |       |       |       |       |         _______|________              ______|______          |
# NP_PPSS VERB_MD VERB_VB PREP_IN NOUN_NN PREP_IN   eight          o___clock     PREP_IN        ADJ_JJ pt_char_per
#    |       |       |       |       |       |        |                |            |             |         |
#   'i'     "'d"   'like'   'to'  'leave' 'before' 'eight'         "o'clock"       'at'        'night'     '.'
#          SIGMA
#     _______|_______
#    |              DLX
#    |        _______|_______________
#    |       |                      DLY
#    |       |        _______________|________________
#    |       |       |                               DLZ
#    |       |       |                ________________|_____________________________________________________
#    |       |       |             PP_NN                                                                    |
#    |       |       |        _______|________________                                                      |
#    |       |       |       |                       KIN                                                    |
#    |       |       |       |        ________________|________________                                     |
#    |       |       |       |       |                               PP_CD                                  |
#    |       |       |       |       |        _________________________|______                              |
#    |       |       |       |       |       |                               KHK                            |
#    |       |       |       |       |       |                 _______________|____________                 |
#    |       |       |       |       |       |             NOUN_CD                       PP_NN              |
#    |       |       |       |       |       |         _______|________              ______|______          |
# NP_PPSS VERB_MD VERB_VB PREP_IN NOUN_NN PREP_IN   eight          o___clock     PREP_IN       NOUN_NN pt_char_per
#    |       |       |       |       |       |        |                |            |             |         |
#   'i'     "'d"   'like'   'to'  'leave' 'before' 'eight'         "o'clock"       'at'        'night'     '.'
#
#                  SIGMA
#     _______________|_______________________
#    |                                      DLX
#    |        _______________________________|________
#    |       |                                       DLY
#    |       |        ________________________________|________________
#    |       |       |                                                DLZ
#    |       |       |                                 ________________|__________________________
#    |       |       |                              PP_NN                                         |
#    |       |       |        ________________________|________________                           |
#    |       |       |       |                                        KIY                         |
#    |       |       |       |                         ________________|________________          |
#    |       |       |       |                      NP_NN                               |         |
#    |       |       |       |        ________________|_______                          |         |
#    |       |       |       |       |                      PP_CD                       |         |
#    |       |       |       |       |        ________________|________                 |         |
#    |       |       |       |       |       |                        KHO               |         |
#    |       |       |       |       |       |                 ________|________        |         |
#    |       |       |       |       |       |             NOUN_CD              |       |         |
#    |       |       |       |       |       |         _______|________         |       |         |
# NP_PPSS VERB_MD VERB_VB PREP_IN NOUN_NN PREP_IN   eight          o___clock PREP_IN NOUN_NN pt_char_per
#    |       |       |       |       |       |        |                |        |       |         |
#   'i'     "'d"   'like'   'to'  'leave' 'before' 'eight'         "o'clock"   'at'  'night'     '.'
#
# (['can', 'you', 'tell', 'me', 'about', 'the', 'flights', 'from', 'saint', 'petersburg', 'to', 'toronto', 'again', '.'], 3)
# 13
#          SIGMA
#     _______|_______
#    |              BJG
#    |        _______|______
#    |       |             BJH
#    |       |        ______|_____________________
#    |       |       |                           BJI
#    |       |       |       _____________________|_________________________
#    |       |       |      |                                              BJJ
#    |       |       |      |                      _________________________|________________________________________________________
#    |       |       |      |                   NP_NNS                                                                               |
#    |       |       |      |               ______|_________________                                                                 |
#    |       |       |      |              |                       KAS                                                               |
#    |       |       |      |              |                ________|_________________                                               |
#    |       |       |      |              |               |                        PP_NP                                            |
#    |       |       |      |              |               |         _________________|__________                                    |
#    |       |       |      |              |               |        |                           ITY                                  |
#    |       |       |      |              |               |        |        ____________________|_____                              |
#    |       |       |      |              |               |        |       |                         ITZ                            |
#    |       |       |      |              |               |        |       |          ________________|______                       |
#    |       |       |      |              |               |        |       |         |                     PP_NP                    |
#    |       |       |      |              |               |        |       |         |           ____________|______                |
#    |       |       |      |            AVP_RB            |        |       |         |          |                  KKY              |
#    |       |       |      |        ______|______         |        |       |         |          |             ______|_____          |
# VERB_MD NP_PPSS VERB_VB NP_PPO  AVP_RB        ADV_RB  NOUN_NNS PREP_IN  NP_NP    NOUN_NP    PREP_IN      NOUN_NP       AVP_RB pt_char_per
#    |       |       |      |       |             |        |        |       |         |          |            |            |         |
#  'can'   'you'   'tell'  'me'  'about'        'the'  'flights'  'from' 'saint' 'petersburg'   'to'      'toronto'     'again'     '.'
#          SIGMA
#     _______|_______
#    |              BJG
#    |        _______|______
#    |       |             BJH
#    |       |        ______|_____________________
#    |       |       |                           BJI
#    |       |       |       _____________________|_________________________
#    |       |       |      |                                              BJJ
#    |       |       |      |                      _________________________|______________________________________________________________
#    |       |       |      |                   NP_NNS                                                                                     |
#    |       |       |      |               ______|_________________                                                                       |
#    |       |       |      |              |                       KAS                                                                     |
#    |       |       |      |              |                ________|_________________                                                     |
#    |       |       |      |              |               |                        PP_NP                                                  |
#    |       |       |      |              |               |         _________________|__________                                          |
#    |       |       |      |              |               |        |                           KLD                                        |
#    |       |       |      |              |               |        |        ____________________|________                                 |
#    |       |       |      |              |               |        |       |                         NAPPOS_NP                            |
#    |       |       |      |              |               |        |       |          ___________________|_________                       |
#    |       |       |      |              |               |        |       |         |                           PP_NP                    |
#    |       |       |      |              |               |        |       |         |           __________________|______                |
#    |       |       |      |            AVP_RB            |        |       |         |          |                        KKY              |
#    |       |       |      |        ______|______         |        |       |         |          |                   ______|_____          |
# VERB_MD NP_PPSS VERB_VB NP_PPO  AVP_RB        ADV_RB  NOUN_NNS PREP_IN NOUN_NP   NOUN_NP    PREP_IN            NOUN_NP       AVP_RB pt_char_per
#    |       |       |      |       |             |        |        |       |         |          |                  |            |         |
#  'can'   'you'   'tell'  'me'  'about'        'the'  'flights'  'from' 'saint' 'petersburg'   'to'            'toronto'     'again'     '.'
#
#          SIGMA
#     _______|_______
#    |              BJG
#    |        _______|______
#    |       |             BJH
#    |       |        ______|_____________________
#    |       |       |                           BJI
#    |       |       |       _____________________|_________________________
#    |       |       |      |                                              BJJ
#    |       |       |      |                      _________________________|____________________________________________________________
#    |       |       |      |                   NP_NNS                                                                                   |
#    |       |       |      |               ______|_________________                                                                     |
#    |       |       |      |              |                       KAS                                                                   |
#    |       |       |      |              |                ________|_________________________                                           |
#    |       |       |      |              |               |                                PP_NP                                        |
#    |       |       |      |              |               |         _________________________|__________                                |
#    |       |       |      |              |               |        |                                   KLJ                              |
#    |       |       |      |              |               |        |                ____________________|________                       |
#    |       |       |      |              |               |        |               |                           PP_NP                    |
#    |       |       |      |              |               |        |               |                     ________|______                |
#    |       |       |      |            AVP_RB            |        |            NOUN_NP                 |              KKY              |
#    |       |       |      |        ______|______         |        |        _______|_________           |         ______|_____          |
# VERB_MD NP_PPSS VERB_VB NP_PPO  AVP_RB        ADV_RB  NOUN_NNS PREP_IN  saint           petersburg  PREP_IN  NOUN_NP       AVP_RB pt_char_per
#    |       |       |      |       |             |        |        |       |                 |          |        |            |         |
#  'can'   'you'   'tell'  'me'  'about'        'the'  'flights'  'from' 'saint'         'petersburg'   'to'  'toronto'     'again'     '.'
